# %% [markdown]
# <a href="https://colab.research.google.com/github/txusser/Master_IA_Sanidad/blob/main/Modulo_2/2_3_3_Matriz_de__correlacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Cargamos los datos de nuestro archivo CSV
data_file = 'https://github.com/txusser/Master_IA_Sanidad/blob/main/Modulo_2/datos/heart.csv'
data_file = 'https://github.com/txusser/Master_IA_Sanidad/raw/main/Modulo_2/datos/diabetic_data.csv'
# Una opción diferente
# !wget 'https://github.com/txusser/Master_IA_Sanidad/blob/main/Modulo_2/datos/heart.csv' .

# df = pd.read_csv('heart.csv', error_bad_lines=False, sep=',', header=None)
df = pd.read_csv(data_file, sep=',')
print(df.head())
# Out:
#    encounter_id  patient_nbr             race  ... change diabetesMed readmitted
# 0       2278392      8222157        Caucasian  ...     No          No         NO
# 1        149190     55629189        Caucasian  ...     Ch         Yes        >30
# 2         64410     86047875  AfricanAmerican  ...     No         Yes         NO
# 3        500364     82442376        Caucasian  ...     Ch         Yes         NO
# 4         16680     42519267        Caucasian  ...     Ch         Yes         NO
#
# [5 rows x 50 columns]

# %%
from matplotlib import pyplot as plt
import numpy as np

# data = read_csv(Path, names = names)
cols = df.columns

print("Primeras columnas del dataset:")
[print(" -", col) for col in cols[0:12]]

correlations = df.corr()
print("Valores de correlación:\n", correlations)

fig = plt.figure(1, figsize=(20,20))
ax = fig.add_subplot(111)
cax = ax.matshow(correlations, vmin=-1, vmax=1, cmap='RdYlGn')
fig.colorbar(cax)

cols = [col[0:12] for col in cols[0:12]]

ticks = np.arange(0, len(cols)+1, 1)
ax.set_xticks(ticks)
ax.set_yticks(ticks)
ax.set_xticklabels(cols, rotation=45)
ax.set_yticklabels(cols, rotation=45)
fig.suptitle("Matriz de correlación de variables")

plt.show()

corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# Primeras columnas del dataset:
#  - encounter_id
#  - patient_nbr
#  - race
#  - gender
#  - age
#  - weight
#  - admission_type_id
#  - discharge_disposition_id
#  - admission_source_id
#  - time_in_hospital
#  - payer_code
#  - medical_specialty
# Valores de correlación:
#                            encounter_id  ...  number_diagnoses
# encounter_id                  1.000000  ...          0.265149
# patient_nbr                   0.512028  ...          0.226847
# admission_type_id            -0.158961  ...         -0.117126
# discharge_disposition_id     -0.132876  ...          0.046891
# admission_source_id          -0.112402  ...          0.072114
# time_in_hospital             -0.062221  ...          0.220186
# num_lab_procedures           -0.026062  ...          0.152773
# num_procedures               -0.014225  ...          0.073734
# num_medications               0.076113  ...          0.261526
# number_outpatient             0.103756  ...          0.094152
# number_emergency              0.082803  ...          0.055539
# number_inpatient              0.030962  ...          0.104710
# number_diagnoses              0.265149  ...          1.000000
#
# [13 rows x 13 columns]
# <style  type="text/css" >
# #T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col0,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col1,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col2,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col3,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col4,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row5_col5,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row6_col6,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row7_col7,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row8_col8,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row9_col9,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row10_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row11_col11,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row12_col12{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col1{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col2,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col3,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col5,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col3,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col0,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col6,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col12,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col1,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col7,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col8,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row7_col4,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row7_col9,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row7_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row7_col11{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col4,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col0{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col6,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row11_col2{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col7,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col7,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row7_col1{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col8,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row7_col0,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row8_col11,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row9_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row10_col6{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col9,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col2,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col9,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col8,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row5_col2,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row11_col5{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row6_col0,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row10_col9,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row12_col9{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col11,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col4,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col1,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row12_col10{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row0_col12{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col0{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col5,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row12_col2{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col6,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row8_col1,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row11_col3{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col8,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col11,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row8_col4{
#             background-color:  #506bda;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col11,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row9_col7,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row9_col8{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row1_col12,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row6_col8{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col1,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row5_col4,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row9_col3,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row11_col8{
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col3{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col4,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col5,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row9_col1{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col5{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col7{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col9,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row8_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row9_col5,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row10_col5{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col9,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row6_col9{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row2_col11{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col2,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row10_col0{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col4,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col7,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col3,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row6_col1,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row7_col3{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col6,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col12{
#             background-color:  #688aef;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col8,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row10_col12{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col10,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row5_col9,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row6_col2{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row3_col11{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col0{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col2,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row9_col0{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_580fcb9e_3dbc_11ec_812c_0242ac1c0002row4_col5,#T_580fcb9e_3dbc_11ec_812c_0242ac1c0
